# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
sample_submission = pd.read_csv('/Users/ugwumsiegbuna/Downloads/SampleSubmission.csv')

# %%
sample_submission.head()
# Out:
#           ID  total_cost
# 0     tour_1           0
# 1   tour_100           0
# 2  tour_1001           0
# 3  tour_1006           0
# 4  tour_1009           0

# %%
train = pd.read_csv('/Users/ugwumsiegbuna/Downloads/Train.csv')

# %%
train.head()
# Out:
#           ID         country age_group        travel_with  total_female  \
# 0     tour_0      SWIZERLAND     45-64  Friends/Relatives           1.0
# 1    tour_10  UNITED KINGDOM     25-44                NaN           1.0
# 2  tour_1000  UNITED KINGDOM     25-44              Alone           0.0
# 3  tour_1002  UNITED KINGDOM     25-44             Spouse           1.0
# 4  tour_1004           CHINA      1-24                NaN           1.0
#
#    total_male                         purpose     main_activity  \
# 0         1.0            Leisure and Holidays  Wildlife tourism
# 1         0.0            Leisure and Holidays  Cultural tourism
# 2         1.0  Visiting Friends and Relatives  Cultural tourism
# 3         1.0            Leisure and Holidays  Wildlife tourism
# 4         0.0            Leisure and Holidays  Wildlife tourism
#
#                     info_source tour_arrangement  ... package_transport_tz  \
# ...

# %%
pd.set_option('max_columns', None)

# %%
train.head()
# Out:
#           ID         country age_group        travel_with  total_female  \
# 0     tour_0      SWIZERLAND     45-64  Friends/Relatives           1.0
# 1    tour_10  UNITED KINGDOM     25-44                NaN           1.0
# 2  tour_1000  UNITED KINGDOM     25-44              Alone           0.0
# 3  tour_1002  UNITED KINGDOM     25-44             Spouse           1.0
# 4  tour_1004           CHINA      1-24                NaN           1.0
#
#    total_male                         purpose     main_activity  \
# 0         1.0            Leisure and Holidays  Wildlife tourism
# 1         0.0            Leisure and Holidays  Cultural tourism
# 2         1.0  Visiting Friends and Relatives  Cultural tourism
# 3         1.0            Leisure and Holidays  Wildlife tourism
# 4         0.0            Leisure and Holidays  Wildlife tourism
#
#                     info_source tour_arrangement package_transport_int  \
# 0            Friends, relatives      Independent                    No
# ...

# %%
train.groupby('country').first()
# Out:
#                                  ID age_group          travel_with  \
# country
# ALGERIA                    tour_103     25-44               Spouse
# ANGOLA                    tour_2611     45-64               Spouse
# ARGENTINA                 tour_5128     45-64               Spouse
# AUSTRALIA                 tour_1078     25-44    Friends/Relatives
# AUSTRIA                   tour_1021     45-64    Friends/Relatives
# ...                             ...       ...                  ...
# UNITED STATES OF AMERICA  tour_1008     45-64    Friends/Relatives
# URUGUAY                   tour_5468     25-44    Friends/Relatives
# YEMEN                     tour_1088     45-64  Spouse and Children
# ZAMBIA                    tour_1123     45-64    Friends/Relatives
# ZIMBABWE                  tour_1122     25-44  Spouse and Children
#
#                           total_female  total_male  \
# country
# ALGERIA                            1.0         1.0
# ...
