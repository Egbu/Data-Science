# %% [markdown]
# Import all relevant libraries

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline

# %%
start = datetime.datetime(2006, 1, 1)
end = datetime.datetime(2016, 1, 1)
iex_key = 'pk_32af36dd64e047e7a64c8f9a3f2b6267'
alpha_vantage_key =  'YVW7BSHF8MTGR4JD'

# %% [markdown]
# Read historical Finncial Data for companies using TIckers as variable names; Bank of America (BAC), Citi Group (C), Goldman Sachs (GS), JP Morgan (JPM), Morgan Stanley (MS), Well Fargo (WFC)

# %%
# Bank of America 
BAC = data.DataReader('BAC','av-daily',start,end,api_key=alpha_vantage_key)

# CitiGroup
C = data.DataReader('C','av-daily',start,end,api_key=alpha_vantage_key)

# Goldman Sachs
GS = data.DataReader('GS','av-daily',start,end,api_key=alpha_vantage_key)

# JP Morgan Chase
JPM = data.DataReader('JPM','av-daily',start,end,api_key=alpha_vantage_key)

# Morgan Stanley
MS = data.DataReader('MS','av-daily',start,end,api_key=alpha_vantage_key)

# %%
# Wells Fargo
WFC = data.DataReader('WFC','av-daily',start,end,api_key=alpha_vantage_key)

# %%
tickers = ['BAC','C','GS','JPM','MS','WFC']

# %%
bank_stocks = pd.concat([BAC,C,GS,JPM,MS,WFC],axis=1,keys=tickers)

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %%
bank_stocks.head()
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    open   high    low  close    volume   open   high    low  close
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  49.00  49.38  48.11  49.29
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  48.86  49.10  48.35  48.38
# 2006-01-05   46.58  46.83  46.32  46.64  14970700  48.44  48.78  48.40  48.62
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  48.88  48.90  48.20  48.62
# 2006-01-09   46.72  46.97  46.36  46.60  15619400  48.60  48.74  48.30  48.39
#
# Bank Ticker            ...     MS                                    WFC  \
# Stock Info     volume  ...   open   high      low  close   volume   open
# 2006-01-03   15376000  ...  57.17  58.49  56.7400  58.31  5377000  63.20
# 2006-01-04   18709000  ...  58.70  59.28  58.3500  58.35  7977800  63.60
# 2006-01-05   11431000  ...  58.55  58.59  58.0200  58.51  5778000  63.00
# ...

# %%
bank_stocks.xs(key='close',axis=1,level=1).max()
# Out:
# Bank Ticker
# BAC     54.90
# C       60.34
# GS     247.92
# JPM     70.08
# MS      89.30
# WFC     73.00
# dtype: float64

# %%
returns = pd.DataFrame()

# %%
for tick in tickers:
    returns[tick+' Returns'] = bank_stocks[tick]['close'].pct_change()
returns.head()
# Out:
#             BAC Returns  C Returns  GS Returns  JPM Returns  MS Returns  \
# 2006-01-03          NaN        NaN         NaN          NaN         NaN
# 2006-01-04    -0.010620  -0.018462   -0.013812    -0.014183    0.000686
# 2006-01-05     0.001288   0.004961   -0.000393     0.003029    0.002742
# 2006-01-06    -0.001501   0.000000    0.014169     0.007046    0.001025
# 2006-01-09     0.000644  -0.004731    0.012030     0.016242    0.010586
#
#             WFC Returns
# 2006-01-03          NaN
# 2006-01-04    -0.011599
# 2006-01-05    -0.001110
# 2006-01-06     0.005874
# 2006-01-09    -0.000158

# %%
import seaborn as sns
sns.pairplot(returns)

# %% [markdown]
# The lowest single day drop in the entire period

# %%
returns.idxmin()
# Out:
# BAC Returns    2009-01-20
# C Returns      2009-02-27
# GS Returns     2009-01-20
# JPM Returns    2009-01-20
# MS Returns     2008-10-09
# WFC Returns    2006-08-14
# dtype: object

# %% [markdown]
# The highest single day gain in the entire period

# %%
returns.idxmax()
# Out:
# BAC Returns    2009-04-09
# C Returns      2011-05-09
# GS Returns     2008-11-24
# JPM Returns    2009-01-21
# MS Returns     2008-10-13
# WFC Returns    2008-07-16
# dtype: object

# %% [markdown]
# Figuring out which was the riskiest stock over the entire period

# %%
returns.std()
# Out:
# BAC Returns    0.036628
# C Returns      0.179066
# GS Returns     0.025358
# JPM Returns    0.027651
# MS Returns     0.037821
# WFC Returns    0.031838
# dtype: float64

# %% [markdown]
# Figuring out which was the riskiest stock in 2015

# %%
returns['2015-01-01':'2015-12-31'].std()
# Out:
# BAC Returns    0.016163
# C Returns      0.015289
# GS Returns     0.014046
# JPM Returns    0.014017
# MS Returns     0.016249
# WFC Returns    0.012591
# dtype: float64

# %%
sns.displot(returns['MS Returns'].loc['2015-01-01':'2015-12-31'],bins=100)

# %%
sns.displot(returns['C Returns'].loc['2008-01-01':'2008-12-31'],bins=100)

# %%
import matplotlib.pyplot as plt
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# Simple plot of the closing price of all the bank Stocks for the entire time series

# %%
plt.figure(figsize=(35,12))
bank_stocks.xs(key='close',axis=1,level=1).plot()
plt.legend(bbox_to_anchor=(1,1))

# %% [markdown]
# Interactive plot using plotly

# %%
bank_stocks.xs(key='close',axis=1,level=1).iplot()
# Out:
# <div>                            <div id="c1a794be-14f3-4e5d-a650-fb1a80e4341f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Moving Averages

# %% [markdown]
# Here I try to calculate and plot the moving 30-day average against the close price for Bank of America Stock in 2008

# %%
plt.figure(figsize=(12,6))
bank_stocks['BAC']['close'].loc['2008-01-01':'2009-01-01'].rolling(30).mean().plot(label='30 Day Average')
bank_stocks['BAC']['close'].loc['2008-01-01':'2009-01-01'].plot(label='BAC Close')
plt.legend()

# %%
sns.heatmap(bank_stocks.xs(key='close',axis=1,level=1).corr(),annot=True)
# Out:
# <AxesSubplot:xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %%
sns.clustermap(bank_stocks.xs(key='close',axis=1,level=1).corr(),annot=True)

# %% [markdown]
# Creating the heatmap above using Plotly

# %%
close_corr = bank_stocks.xs(key='close',axis=1,level='Stock Info').corr()
close_corr.iplot(kind='heatmap',colorscale='rdylbu')
# Out:
# <div>                            <div id="ea7e441f-0f0a-4c74-83ad-d023e5a5feb2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
