# %%
import seaborn as sns

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')
flights = sns.load_dataset('flights')
iris = sns.load_dataset('iris')
#sns.set_style('whitegrid')
titanic = sns.load_dataset('titanic')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.displot(tips['total_bill'],bins=30)

# %%
sns.jointplot(x='tip',y='total_bill',data=tips)

# %%
sns.pairplot(tips)

# %%
sns.rugplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.barplot(x='sex',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(x='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.boxplot(x='day',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
fp = flights.pivot_table(index='month',columns='year',values='passengers')
sns.heatmap(fp,linecolor='white',linewidth=1)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.clustermap(fp)

# %%
df1 = pd.read_csv('/Users/ugwumsiegbuna/Downloads/Refactored_Py_DS_ML_Bootcamp-master/07-Pandas-Built-in-Data-Viz/df1',index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1['A'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
df2 = pd.read_csv('/Users/ugwumsiegbuna/Downloads/Refactored_Py_DS_ML_Bootcamp-master/07-Pandas-Built-in-Data-Viz/df2')
df3 = pd.read_csv('/Users/ugwumsiegbuna/Downloads/Refactored_Py_DS_ML_Bootcamp-master/07-Pandas-Built-in-Data-Viz/df3')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df2.plot.area()
# Out:
# <AxesSubplot:>

# %%
sns.set_style(style='darkgrid')
df3.plot.scatter(x='a',y='b',s=50,c='red',figsize=(12,3))
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df3['a'].hist(bins=25)
# Out:
# <AxesSubplot:>

# %%
df3[['a','b']].plot.box()
# Out:
# <AxesSubplot:>

# %%
from plotly import __version__
import cufflinks as cf
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
import plotly.graph_objs as go

# %%
print(__version__)
# Out:
# 5.1.0

# %%
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
# ...

# %%
ddf = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
ddf2 = pd.DataFrame({'Category':['A','B','C'],'Values':[12,15,22]})

# %%
ddf.iplot()
# Out:
# <div>                            <div id="ed528a3b-961c-42a1-898d-17beb069fcce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
ddf.iplot(kind='scatter',x='A',y='B',mode='markers')
# Out:
# <div>                            <div id="b35e8b36-b343-4010-bb21-2d64584db614" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
ddf2.iplot(kind='bar',x='Category',y='Values')
# Out:
# <div>                            <div id="0e89d050-43c8-4030-832d-608712f88ffc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
ddf.iplot(kind='box')
# Out:
# <div>                            <div id="748c910b-803d-4776-8458-d3a83c2adfb7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
ddf3 = pd.DataFrame({'X':[1,2,3,4,5],'Y':[300,200,500,100,400],'Z':[1000,900,800,700,6001]})

# %%
ddf3.iplot(kind='surface')
# Out:
# <div>                            <div id="a8a3de10-7946-496f-a494-49a995851cf4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
ddf['A'].iplot(kind='hist',bins=75)
# Out:
# <div>                            <div id="e250cd89-45d6-4a1e-8fdc-0510ef754e2f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
cov = pd.read_html('/Users/ugwumsiegbuna/Desktop/COVID Live Update_ 185,975,053 Cases and 4,020,254 Deaths from the Coronavirus - Worldometer.html')

# %%
code_df = pd.DataFrame(data=['ABW',
'AFG',
'AGO',
'AIA',
'ALA',
'ALB',
'AND',
'ARE',
'ARG',
'ARM',
'ASM',
'ATA',
'ATF',
'ATG',
'AUS',
'AUT',
'AZE',
'BDI',
'BEL',
'BEN',
'BES',
'BFA',
'BGD',
'BGR',
'BHR',
'BHS',
'BIH',
'BLM',
'BLR',
'BLZ',
'BMU',
'BOL',
'BRA',
'BRB',
'BRN',
'BTN',
'BVT',
'BWA',
'CAF',
'CAN',
'CCK',
'CHE',
'CHL',
'CHN',
'CIV',
'CMR',
'COD',
'COG',
'COK',
'COL',
'COM',
'CPV',
'CRI',
'CUB',
'CUW',
'CXR',
'CYM',
'CYP',
'CZE',
'DEU',
'DJI',
'DMA',
'DNK',
'DOM',
'DZA',
'ECU',
'EGY',
'ERI',
'ESH',
'ESP',
'EST',
'ETH',
'FIN',
'FJI',
'FLK',
'FRA',
'FRO',
'FSM',
'GAB',
'GBR',
'GEO',
'GGY',
'GHA',
'GIB',
'GIN',
'GLP',
'GMB',
'GNB',
'GNQ',
'GRC',
'GRD',
'GRL',
'GTM',
'GUF',
'GUM',
'GUY',
'HKG',
'HMD',
'HND',
'HRV',
'HTI',
'HUN',
'IDN',
'IMN',
'IND',
'IOT',
'IRL',
'IRN',
'IRQ',
'ISL',
'ISR',
'ITA',
'JAM',
'JEY',
'JOR',
'JPN',
'KAZ',
'KEN',
'KGZ',
'KHM',
'KIR',
'KNA',
'KOR',
'KWT',
'LAO',
'LBN',
'LBR',
'LBY',
'LCA',
'LIE',
'LKA',
'LSO',
'LTU',
'LUX',
'LVA',
'MAC',
'MAF',
'MAR',
'MCO',
'MDA',
'MDG',
'MDV',
'MEX',
'MHL',
'MKD',
'MLI',
'MLT',
'MMR',
'MNE',
'MNG',
'MNP',
'MOZ',
'MRT',
'MSR',
'MTQ',
'MUS',
'MWI',
'MYS',
'MYT',
'NAM',
'NCL',
'NER',
'NFK',
'NGA',
'NIC',
'NIU',
'NLD',
'NOR',
'NPL',
'NRU',
'NZL',
'OMN',
'PAK',
'PAN',
'PCN',
'PER',
'PHL',
'PLW',
'PNG',
'POL',
'PRI',
'PRK',
'PRT',
'PRY',
'PSE',
'PYF',
'QAT',
'REU',
'ROU',
'RUS',
'RWA',
'SAU',
'SDN',
'SEN',
'SGP',
'SGS',
'SHN',
'SJM',
'SLB',
'SLE',
'SLV',
'SMR',
'SOM',
'SPM',
'SRB',
'SSD',
'STP',
'SUR',
'SVK',
'SVN',
'SWE',
'SWZ',
'SXM',
'SYC',
'SYR',
'TCA',
'TCD',
'TGO',
'THA',
'TJK',  
'TKL',  
'TKM',
'TLS',
'TON',
'TTO',
'TUN',
'TUR',
'TUV',
'TWN',
'TZA',
'UGA',
'UKR',
'UMI',
'URY',
'USA',
'UZB',
'VAT',
'VCT',
'VEN',
'VGB',
'VIR',
'VNM',
'VUT',
'WLF',
'WSM',
'YEM',
'ZAF',
'ZMB',
'ZWE'])

code_df.head()
# Out:
#      0
# 0  ABW
# 1  AFG
# 2  AGO
# 3  AIA
# 4  ALA

# %%
iso_codes = pd.DataFrame(data={'ISO CODES':[0,'USA',
                              'IND',
                              'BRA',
                              'FRA',
                              'RUS',
                              'TUR',
                              'GBR', 
                                'ARG','COL','ITA','ESP','DEU','IRN','POL','MEX','IDN','UKR','ZAF','PER','NLD','CZE','CHL','PHL',
                                'CAN','IRQ','SWE','BEl','ROU','BGD','PAK','PRT','ISR','JPN','MYS','HUN','JOR','SRB','CHE','NPL'
                                'AUT','ARE','LBN','MAR','SAU','ECU','TUN','BOL','KAZ','PRY','GRC','BLR','BGR','PAN','SVK','CRI',
                                'URY','GEO','KWT','HRV','AZE','DOM','PSE','GTM','THA','DNK','EGY','OMN','VEN','LTU','ETH','IRL',
                                'HND','LKA','BHR','SVN','MDA','ARM','QAT','CUB','BIH','LBY','KEN','MMR','ZMB','NGA','KOR','MKD',
                                'DZA','LVA','KGZ','NOR','ALB','MNG','EST','AFG','UZB','MNE','NAM','FIN','GHA','CHN','UGA','MOZ',
                                'CMR','CYP','SLV','MDV','BWA','LUX','SGP','ZWE','KHM','JAM','CIV','RWA','SEN','COD','MGD','AGO',
                                'MWI','SDN','TTO','CPV','REU','AUS','MLT','GUF','SYR','GAB','GIN','VNM','SUR','MRT','GUY','SWZ',
                                'MYT','HTI','PYF','PNG','GLP','SYC','TWN','SOM','MLI','TGO','AND','TJK','BFA','BLZ','BHS','COG',
                                'MTQ','CUW','HKG','LSO','DJI','ABW','SSD','TLS','GNQ','NIC','BEN','FJI','CAF','YEM','ISL','ERI',
                                'GMB','SLE','BDI','NER','LCA','SMR','LBR','TCD','','GIB','BRB','COM','GNB','LIE','NZL','SXM','MCO',
                                'BMU','LAO','TCA','STP','MAF','BTN','VCT','MUS','BES','IMN','ATG','BLM','FRO','VGB','','CYM','KNA',
                                'TZA','WLF','BRN','DMA','GRD','NCL','AIA','FLK','MAC','GRL','VAT','SPM','MSR','SLB','ESH','','VUT',
                                'MHL','WSM','SHN','FSM',''
                                           ]})

# %%
# def iscd():
#     for x in co['Country,Other']:
#         x in

# %%
co = cov[0].join(iso_codes)
co.head()
#co.set_index('#')
#co.join(iso_codes)
# Out:
#      # Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0  NaN         World   185975053  146685.0    4020254.0     2769.0
# 1  1.0           USA    34646741       NaN     621904.0        NaN
# 2  2.0         India    30709557     987.0     405057.0        NaN
# 3  3.0        Brazil    18909037       NaN     528611.0        NaN
# 4  4.0        France     5794665       NaN     111259.0        NaN
#
#    TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  \
# 0     170181950.0      104702.0   11772849.0           78118.0
# 1      29168313.0           NaN    4856524.0            3815.0
# 2      29843825.0        7360.0     460675.0            8944.0
# 3      17352670.0           NaN    1027756.0            8318.0
# 4       5638432.0           NaN      44974.0             997.0
#
#    Tot Cases/1M pop  Deaths/1M pop   TotalTests  Tests/ 1M pop    Population  \
# 0           23859.0          515.8          NaN            NaN           NaN
# ...

# %%
data = dict(type='choropleth',
           locations=co['ISO CODES'],
           reversescale=True,
           z=co['TotalCases'],
           text=co['Country,Other'],
           colorbar={'title':'Total Confirmed Cases'})

# %%
layout = dict(title='Total COVID19 Cases by Country',
             geo=dict(showframe=False,
                     projection={'type':'mercator'}))

# %%
choromap = go.Figure(data=[data],layout=layout)

# %%
iplot(choromap)
# Out:
# <div>                            <div id="ae6e202a-e112-4b03-88c6-45c9c2842e31" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae6e202a-e112-4b03-88c6-45c9c2842e31")) {                    Plotly.newPlot(                        "ae6e202a-e112-4b03-88c6-45c9c2842e31",                        [{"colorbar":{"title":{"text":"Total Confirmed Cases"}},"locations":[0,"USA","IND","BRA","FRA","RUS","TUR","GBR","ARG","COL","ITA","ESP","DEU","IRN","POL","MEX","IDN","UKR","ZAF","PER","NLD","CZE","CHL","PHL","CAN","IRQ","SWE","BEl","ROU","BGD","PAK","PRT","ISR","JPN","MYS","HUN","JOR","SRB","CHE","NPLAUT","ARE","LBN","MAR","SAU","ECU","TUN","BOL","KAZ","PRY","GRC","BLR","BGR","PAN","SVK","CRI","URY","GEO","KWT","HRV","AZE","DOM","PSE","GTM","THA","DNK","EGY","OMN
# ...
